# %%
import sys
sys.path.append('/eos/project/l/liu/Instrumentation/Scripts')
import metaclass

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fpath = './output/bump_DHZ51-57.twiss'
myio = metaclass.twiss(fpath)

# %%
print(str(myio.NAME[1396])+ ' at '+str(myio.S[1396])+' --> offset = '+str(myio.X[1396]))
print(str(myio.NAME[1424])+ ' at '+str(myio.S[1424])+' --> offset = '+str(myio.X[1424]))
print(str(myio.NAME[1450])+ ' at '+str(myio.S[1450])+' --> offset = '+str(myio.X[1450]))
# Out:
# PR.BPM53 at 327.565636 --> offset = -0.001505992407
# PR.BPM54 at 333.6688213 --> offset = -0.001274995169
# PR.BPM55 at 339.5720066 --> offset = -0.001517145313

# %%
# n2
fig, ax = plt.subplots(1, figsize=(10,7))
plt.plot(myio.S, myio.X,'k-')

plt.axvline(x=327.565636)
plt.axvline(x=333.6688213)
plt.axvline(x=339.5720066)
# Out:
# <img src="data:image/png;base64,..." width="1000">
